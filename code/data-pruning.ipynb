# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pyvista as pv
import pandas as pd
import numpy as np 

## File to work on
survey = pd.read_csv('../data/gem2_for_emagpy.csv')

# %% [markdown]
# ### Determining Lines

# %%
usedLines = []

plt.figure(figsize=(10,10))
#plt.plot(survey['x'].iloc[15000:58000], survey['y'].iloc[15000:58000], c = 'b')

#Line 1 (0 to 920)
plt.plot(survey['x'].iloc[0:920], survey['y'].iloc[0:920])
usedLines.extend(range(0, 920+1))

#Line 2 (1185 to 2070)
plt.plot(survey['x'].iloc[1185:2070], survey['y'].iloc[1185:2070])
usedLines.extend(range(1185, 2070+1))

#Line 3 (2095 to 2980)
plt.plot(survey['x'].iloc[2095:2980], survey['y'].iloc[2095:2980])
usedLines.extend(range(2095, 2980+1))

#Line 4 (3080 to 4995)
plt.plot(survey['x'].iloc[3080:4995], survey['y'].iloc[3080:4995])
usedLines.extend(range(3080, 4995+1))

#Line 5 (5035 to 6500)
plt.plot(survey['x'].iloc[5035:6500], survey['y'].iloc[5035:6500])
usedLines.extend(range(5035, 6500+1))

#Line 6 (6650 to 9580)
plt.plot(survey['x'].iloc[6650:9580], survey['y'].iloc[6650:9580])
usedLines.extend(range(6650, 9580+1))

#Line 7 (9610 to 11880)
plt.plot(survey['x'].iloc[9610:11880], survey['y'].iloc[9610:11880])
usedLines.extend(range(9610, 11880+1))

#Line 8 (12170 to 13820)
plt.plot(survey['x'].iloc[12170:13820], survey['y'].iloc[12170:13820])
usedLines.extend(range(12170, 13820+1))

#Line 9 (14130 to 14870)
plt.plot(survey['x'].iloc[14130:14870], survey['y'].iloc[14130:14870])
usedLines.extend(range(14130, 14870+1))

#Line 10 (14910 to 15720)
plt.plot(survey['x'].iloc[14910:15720], survey['y'].iloc[14910:15720])
usedLines.extend(range(14910, 15720+1))

#Line 11 (15760 to 16430)
plt.plot(survey['x'].iloc[15760:16430], survey['y'].iloc[15760:16430])
usedLines.extend(range(15760, 16430+1))

#Line 12 (16570 to 17520)
plt.plot(survey['x'].iloc[16570:17520], survey['y'].iloc[16570:17520])
usedLines.extend(range(16570, 17520+1))

#Line 13 (17800 to 18545)
plt.plot(survey['x'].iloc[17800:18545], survey['y'].iloc[17800:18545])
usedLines.extend(range(17800, 18545+1))

#Line 14 (18625 to 19435)
plt.plot(survey['x'].iloc[18625:19435], survey['y'].iloc[18625:19435])
usedLines.extend(range(18625, 19435+1))

#Line 15 (19660 to 20645)
plt.plot(survey['x'].iloc[19660:20645], survey['y'].iloc[19660:20645])
usedLines.extend(range(19660, 20645+1))

#Line 16 (20690 to 21965)
plt.plot(survey['x'].iloc[20690:21965], survey['y'].iloc[20690:21965])
usedLines.extend(range(20690, 21965+1))

#Line 17 (22190 to 22800)
plt.plot(survey['x'].iloc[22190:22800], survey['y'].iloc[22190:22800])
usedLines.extend(range(22190, 22800+1))

#Line 18 (22840 to 23425)
plt.plot(survey['x'].iloc[22840:23425], survey['y'].iloc[22840:23425])
usedLines.extend(range(22840, 23425+1))

#Line 19 (25750 to 26350)
plt.plot(survey['x'].iloc[25750:26350], survey['y'].iloc[25750:26350])
usedLines.extend(range(25750, 26350+1))

#Line 20 (26395 to 27060)
plt.plot(survey['x'].iloc[26395:27060], survey['y'].iloc[26395:27060])
usedLines.extend(range(26395, 27060+1))

#Line 21 (27095 to 27830)
plt.plot(survey['x'].iloc[27095:27830], survey['y'].iloc[27095:27830])
usedLines.extend(range(27095, 27830+1))

#Line 22 (27870 to 28510)
plt.plot(survey['x'].iloc[27870:28510], survey['y'].iloc[27870:28510])
usedLines.extend(range(27870, 28510+1))

#Line 23 (28595 to 29300)
plt.plot(survey['x'].iloc[28595:29300], survey['y'].iloc[28595:29300])
usedLines.extend(range(28595, 29300+1))

#Line 24 (30855 to 31570)
plt.plot(survey['x'].iloc[30855:31570], survey['y'].iloc[30855:31570])
usedLines.extend(range(30855, 31570+1))

#Line 25 (31650 to 32420)
plt.plot(survey['x'].iloc[31650:32420], survey['y'].iloc[31650:32420])
usedLines.extend(range(31650, 32420+1))

#Line 26 (32490 to 33420)
plt.plot(survey['x'].iloc[32490:33420], survey['y'].iloc[32490:33420])
usedLines.extend(range(32490, 33420+1))

#Line 27 (34470 to 36110)
plt.plot(survey['x'].iloc[34470:36110], survey['y'].iloc[34470:36110])
usedLines.extend(range(34470, 36110+1))

#Line 28 (36870 to 38900)
plt.plot(survey['x'].iloc[36870:38900], survey['y'].iloc[36870:38900])
usedLines.extend(range(36870, 38900+1))

#Line 29 (39000 to 41100)
plt.plot(survey['x'].iloc[39000:41100], survey['y'].iloc[39000:41100])
usedLines.extend(range(39000, 41100+1))

#Line 30 (41530 to 44095)
plt.plot(survey['x'].iloc[41530:44095], survey['y'].iloc[41530:44095])
usedLines.extend(range(41530, 44095+1))

#Line 31 (44190 to 45900)
plt.plot(survey['x'].iloc[44190:45900], survey['y'].iloc[44190:45900])
usedLines.extend(range(44190, 45900+1))

#Line 32 (46170 to 47250)
plt.plot(survey['x'].iloc[46170:47250], survey['y'].iloc[46170:47250])
usedLines.extend(range(46170, 47250+1))

#Line 33 (47520 to 48400)
plt.plot(survey['x'].iloc[47520:48400], survey['y'].iloc[47520:48400])
usedLines.extend(range(47520, 48400+1))

#Line 34 (48460 to 49450)
plt.plot(survey['x'].iloc[48460:49450], survey['y'].iloc[48460:49450])
usedLines.extend(range(48460, 49450+1))

#Line 35 (49770 to 50770)
plt.plot(survey['x'].iloc[49770:50770], survey['y'].iloc[49770:50770])

#Line 36 (50900 to 51690)
plt.plot(survey['x'].iloc[50900:51690], survey['y'].iloc[50900:51690])
usedLines.extend(range(50900, 51690+1))

#Line 37 (51970 to 52780)
plt.plot(survey['x'].iloc[51970:52780], survey['y'].iloc[51970:52780])
usedLines.extend(range(51970, 52780+1))

#Line 38 (53000 to 53660)
plt.plot(survey['x'].iloc[53000:53660], survey['y'].iloc[53000:53660])
usedLines.extend(range(53000, 53660+1))

#Line 39 (54040 to 55185)
plt.plot(survey['x'].iloc[54040:55185], survey['y'].iloc[54040:55185])
usedLines.extend(range(54040, 55185+1))

#Line 40 (55260 to 56470)
plt.plot(survey['x'].iloc[55260:56470], survey['y'].iloc[55260:56470])
usedLines.extend(range(55260, 56470+1))

#Line 41 (56550 to 57590)
plt.plot(survey['x'].iloc[56550:57590], survey['y'].iloc[56550:57590])
usedLines.extend(range(56550, 57590+1))

plt.title("Edge Corrected FDEM Survey Lines")
plt.xlabel("Easting (m)")
plt.ylabel("Northing (m)")
# Out:
# Text(0, 0.5, 'Northing (m)')

# %% [markdown]
# ### Create new CSV with fixed Data

# %%
new_df = []

for index, row in survey.iterrows():
    for num in usedLines:
        if index == num:
            new_df.append(row)

# %%
df = pd.DataFrame(new_df)
plt.Figure(figsize=(25,5))
plt.plot(df['ssssssssssssHCP1.6f450h0.15'])
plt.plot(df['Unnamed: 0'], df['HCP1.6f1530h0.15'])
plt.plot(df['Unnamed: 0'], df['HCP1.6f5310h0.15'])
plt.plot(df['Unnamed: 0'], df['HCP1.6f18330h0.15'])
plt.plot(df['Unnamed: 0'], df['HCP1.6f63030h0.15'])
plt.show()

test = []

for i, row in df.iterrows():
    if (row['ssssssssssssHCP1.6f450h0.15'] > 1100 or row['ssssssssssssHCP1.6f450h0.15'] < 0) and i < 25000:
        df.drop(index=i, inplace=True)
    elif row['HCP1.6f1530h0.15'] > 225 or row['HCP1.6f1530h0.15'] < -25:
        df.drop(index = i, inplace=True)
    elif row['HCP1.6f5310h0.15'] > 110 or row['HCP1.6f5310h0.15'] < 0:
        df.drop(index = i, inplace=True)
    elif row['HCP1.6f18330h0.15'] > 80 or row['HCP1.6f18330h0.15'] < 0:
        df.drop(index = i, inplace=True)
    elif row['HCP1.6f63030h0.15'] > 70 or row['HCP1.6f63030h0.15'] < 0:
        df.drop(index = i, inplace=True) 

plt.scatter(df['Unnamed: 0'], df['ssssssssssssHCP1.6f450h0.15'], marker=".")
plt.scatter(df['Unnamed: 0'], df['HCP1.6f1530h0.15'], marker=".")
plt.scatter(df['Unnamed: 0'], df['HCP1.6f5310h0.15'], marker=".")
plt.scatter(df['Unnamed: 0'], df['HCP1.6f18330h0.15'], marker=".")
plt.scatter(df['Unnamed: 0'], df['HCP1.6f63030h0.15'], marker=".")

# %%
df_skipped = []
count = 0
for i, row in df.iterrows():
    if count%20 == 0:
        df_skipped.append(row)
    count+=1

df_skipped = pd.DataFrame(df_skipped)

plt.plot()
plt.scatter(df_skipped['Unnamed: 0'], df_skipped['ssssssssssssHCP1.6f450h0.15'], marker=".")
plt.scatter(df_skipped['Unnamed: 0'], df_skipped['HCP1.6f1530h0.15'], marker=".")
plt.scatter(df_skipped['Unnamed: 0'], df_skipped['HCP1.6f5310h0.15'], marker=".")
plt.scatter(df_skipped['Unnamed: 0'], df_skipped['HCP1.6f18330h0.15'], marker=".")
plt.scatter(df_skipped['Unnamed: 0'], df_skipped['HCP1.6f63030h0.15'], marker=".")

# %%
plt.scatter(df_skipped['x'], df_skipped['y'], marker = '.')

# %%
df_skipped.to_csv(r"C:\Users\ianph\Documents\FDEM_Project_FC_2025\data\edge_adjusted_gem_data_noise_reduction_20skip.csv")

# %%
df.to_csv(r"C:\Users\ianph\Documents\FDEM_Project_FC_2025\data\edge_adjusted_gem_data_noise_reduction.csv")
